# %%
# defining the function
def add(a,b):
    result = a+b
    return result

# %%
# 2 example calls
print(add(5, 3))  # Output: 8
print(add('hello', 'world'))  # Output: 'helloworld'
# Out:
# 8
# helloworld
